# %%
import pandas as pd
import cPickle as pickle

# %%
scores=pd.read_csv("Assignment 3 Sentiment Scores (2).csv")
reviews=pd.read_csv("Assignment 3 Edmunds Posts.csv", usecols=[0])
data=scores.join(reviews)

# %%
data.ix[0]
# Out:
# ES                                                       NaN
# LS                                                       NaN
# RX                                                         4
# A8                                                         3
# A6                                                       NaN
# 3series                                                  NaN
# 5series                                                  NaN
# 7series                                                    5
# XJ                                                         2
# Sclass                                                     1
# Posts      "As a Mercedes fan, I was sad, but I knew that...
# Name: 0, dtype: object

# %%
Lexus = ['ES', 'LS', 'RX']
Audi = ['A8','A6']
BMW = ['3series','5series','7series']
Jaguar = ['XJ']
Mercedes = ['Sclass']

marques = {'ES': 'Lexus','LS':'Lexus','RX':'Lexus','A8':'Audi', 'A6': 'Audi',\
           '3series': 'BMW', '5series':'BMW', '7series': 'BMW', 'XJ': 'Jaguar', 'Sclass':'Mercedes', 'Posts':'Posts'}

index = pd.MultiIndex.from_tuples(marques.items(), names=['model', 'make'])

data_multiindex=data.transpose()

data_multiindex.index.names=['model']

data_multiindex['mark']=pd.Series(marques)

data_multiindex.set_index(['mark'], append=True, inplace=True)

data_multiindex.index=data_multiindex.index.swaplevel(0,1)

dataT=data_multiindex.transpose()

dataT
# Out:
# mark  Lexus           Audi          BMW                 Jaguar Mercedes  \
# model    ES   LS   RX   A8   A6 3series 5series 7series     XJ   Sclass
# 0       NaN  NaN    4    3  NaN     NaN     NaN       5      2        1
# 1       NaN  NaN    3    2    2       2       2       2    NaN      NaN
# 2       NaN    4  NaN  NaN  NaN       3     NaN       3    NaN        3
# 3       NaN    2  NaN    2  NaN     NaN     NaN       2      4        2
# 4       NaN    3    3  NaN  NaN     NaN       2     NaN    NaN        3
# 5       NaN  NaN  NaN    1  NaN     NaN     NaN       3      4        3
# 6       NaN    2  NaN    3  NaN     NaN     NaN       4     -1        3
# 7       NaN  NaN  NaN    3  NaN     NaN     NaN       1      4        2
# 8       NaN    2  NaN    4    3      -2     NaN     NaN    NaN        3
# 9       NaN    4  NaN    2  NaN     NaN     NaN       2    NaN        2
# 10      NaN    2  NaN    4    2       2     NaN     NaN    NaN      NaN
# ...
